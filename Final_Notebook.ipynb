# %% [markdown]
# <a href="https://colab.research.google.com/github/slomit1234/Final-Project/blob/main/Final_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **installations**

# %%
# !pip install torch torchvision torchaudio

# %%
# !pip install git+https://github.com/openai/guided-diffusion.git blobfile tqdm
# Out:
# ...
#   Cloning https://github.com/openai/guided-diffusion.git to /tmp/pip-req-build-_65l9vid
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/guided-diffusion.git /tmp/pip-req-build-_65l9vid
#   Resolved https://github.com/openai/guided-diffusion.git to commit 22e0df8183507e13a7813f8d38d51b072ca1e67c
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 35.4 MB/s eta 0:00:00
# ...
#   Created wheel for guided-diffusion: filename=guided_diffusion-0.0.0-py3-none-any.whl size=1914 sha256=2e43c8de5fbbfb2c753d9585bff90611630e74354333d1b3cee92c5765b9f059
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ryon4dg1/wheels/dd/42/49/9eadb3b70ebd5809969d48e8ce9e6518524adad9386fcac223
# Successfully built guided-diffusion
# ...

# %%
# !pip install mpi4py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.8/464.8 kB 7.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install pyts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 70.7 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-image

# %% [markdown]
# # create the GASF Images
# # train the model - make sure that you change to 2 classes as a start. change the parameter that you sent to the train loop - so it will stop in some point.
# # sample - keep in mind that you will get a numpy array - i attached you our results.

# %%
# !python /content/drive/MyDrive/Colab/gasf_conversion.py
# Out:
# Streaming output truncated to the last 5000 lines.
# | vb_q3      | 5.46e-06 |
# -------------------------
# -------------------------
# | grad_norm  | 0.0725   |
# | loss       | 0.0073   |
# | loss_q0    | 0.0282   |
# | loss_q1    | 0.000372 |
# | loss_q2    | 0.000203 |
# | loss_q3    | 0.00047  |
# | mse        | 0.00483  |
# | mse_q0     | 0.0183   |
# | mse_q1     | 0.00037  |
# | mse_q2     | 0.000202 |
# | mse_q3     | 0.000461 |
# | param_norm | 296      |
# | samples    | 3.87e+05 |
# | step       | 9.68e+04 |
# | vb         | 0.00247  |
# | vb_q0      | 0.00987  |
# | vb_q1      | 2.07e-06 |
# | vb_q2      | 1.13e-06 |
# | vb_q3      | 8.46e-06 |
# -------------------------
# -------------------------
# | grad_norm  | 0.0553   |
# | loss       | 0.00218  |
# | loss_q0    | 0.0188   |
# | loss_q1    | 0.000426 |
# | loss_q2    | 0.000195 |
# | loss_q3    | 0.000336 |
# | mse        | 0.00196  |
# | mse_q0     | 0.0166   |
# | mse_q1     | 0.000424 |
# ...

# %%
#change the train - so it will work on 2 classes (as a start). if you didnt do it - you can use this to try and fix this.
import torch as th
# Load the checkpoint
checkpoint = th.load("/content/drive/MyDrive/Colab/chen/ema_0.9999_180000.pt", map_location="cpu")

# Resize the label embeddings to match 2 classes
checkpoint['label_emb.weight'] = checkpoint['label_emb.weight'][:2]

# Save the modified checkpoint
th.save(checkpoint, "/content/drive/MyDrive/Colab/chen/modified_ema_0.9999_180000.pt")
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-3-c58061b25939> in <cell line: 1>()
# ----> 1 import torch as th
#       2 # Load the checkpoint
#       3 checkpoint = th.load("/content/drive/MyDrive/Colab/chen/ema_0.9999_180000.pt", map_location="cpu")
#       4
#       5 # Resize the label embeddings to match 2 classes
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     288     if USE_GLOBAL_DEPS:
#     289         _load_global_deps()
# --> 290     from torch._C import *  # noqa: F403
#     291
#     292 # Appease the type checker; ordinarily this binding is inserted by the
#
# SystemError: () method: bad call flags

# %%
# !python /content/drive/MyDrive/Colab/scripts/image_sample.py --model_path /content/drive/MyDrive/Colab/chen/ema_0.9999_180000.pt --image_size 128 --num_channels 128 --num_res_blocks 3 --diffusion_steps 1000 --noise_schedule cosine --learn_sigma True --class_cond True --rescale_learned_sigmas False --rescale_timesteps False
# Out:
# CUDA is available. Device: Tesla T4
# Logging to 128/iterate/df/synth_models
# creating model and diffusion...
# Loading model from /content/drive/MyDrive/Colab/chen/modified_ema_0.9999_180000.pt ...
# ...

# %% [markdown]
# # Evaluation

# %%
# !pip install numpy pandas

# %%
# !python /content/drive/MyDrive/Colab/fid.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Unbiased FID score: 199.0768271300388

# %%
# !python /content/drive/MyDrive/Colab/classifier.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Loading data from: /content/drive/MyDrive/Colab/Youtube/mysynth_raw/vid1/13.csv
# Original data shape: (128, 384)
# Loading data from: /content/drive/MyDrive/Colab/ActualForClassification/vid2/deepfp_vid2_8.csv
# Original data shape: (16384, 3)
# Loading data from: /content/drive/MyDrive/Colab/Youtube/mysynth_raw/vid1/9.csv
# Original data shape: (128, 384)
# Loading data from: /content/drive/MyDrive/Colab/ActualForClassification/vid3/deepfp_vid3_4.csv
# Original data shape: (16384, 3)
# Loading data from: /content/drive/MyDrive/Colab/Youtube/mysynth_raw/vid3/11.csv
# Original data shape: (128, 384)
# Loading data from: /content/drive/MyDrive/Colab/Youtube/mysynth_raw/vid2/5.csv
# Original data shape: (128, 384)
# Loading data from: /content/drive/MyDrive/Colab/ActualForClassification/vid3/deepfp_vid3_1.csv
# Original data shape: (16384, 3)
# ...
